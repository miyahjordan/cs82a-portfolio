# %%
def whilemultiplication():
  x = 25
  while x <= 100:
    print(x)
    x += 25
whilemultiplication()
# Out:
# 25
# 50
# 75
# 100

# %%
def formultiplication():
  for x in range(25, 101, 25):
    print(x)
formultiplication()
# Out:
# 25
# 50
# 75
# 100
