# %%
import pandas as pd
df = pd.read_csv('truck.csv')
df.shape
# Out:
# (23, 2)

# %%
df.head(10)
# Out:
#       X     Y
# 0  12.4  11.2
# 1  14.3  12.5
# 2  14.5  12.7
# 3  14.9  13.1
# 4  16.1  14.1
# 5  16.9  14.8
# 6  16.5  14.4
# 7  15.4  13.4
# 8  17.0  14.9
# 9  17.9  15.6

# %%
df.corr(numeric_only=True)
# Out:
#          X        Y
# X  1.00000  0.99854
# Y  0.99854  1.00000

# %%
df.plot.scatter(x='X', y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %% [markdown]
# Theres a strong positive correlation between the list price and the sale of trucks. Looking at the graph, the best list price is between 16-18 thousand dollars as most of the data points seem to reside in that range.
